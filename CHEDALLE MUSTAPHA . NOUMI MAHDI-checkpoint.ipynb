# %%
# Import the pandas library and alias it as 'pd' for convenience.
import pandas as pd 

# Read a CSV file from the specified path into a DataFrame and use ';' as the column separator.
df = pd.read_csv(r"C:/Users/Administrateur.ALITL458/Downloads/titanic-passengers.csv", sep=';')

# Display the DataFrame 'df' to see its contents.
df
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex   Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    male  28.0      0
# 1                              Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                               Jensen, Mr. Hans Peder    male  20.0      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                               Davidson, Mr. Thornton    male  31.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Check for missing values in the DataFrame 'df' and create a boolean DataFrame where True represents missing values.
df.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False  False  False  False   False
# 889        False     False   False  False  False   True  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
# Calculate the number of elements (rows) in the 'Cabin' column of the DataFrame 'df'.
Number_of_elements = len(df['Cabin'])

# Print the number of elements.
print('Number of elements:', Number_of_elements)
# Out:
# Number of elements: 891

# %%
# Print the first few rows of the 'Cabin' column in the DataFrame 'df'.
print(df['Cabin'].head())

# Check for missing values in the first few rows of the 'Cabin' column and print the result.
print(df['Cabin'].head().isnull())
# Out:
# 0      NaN
# 1    F G73
# 2      NaN
# 3      NaN
# 4      B71
# Name: Cabin, dtype: object
# 0     True
# 1    False
# 2     True
# 3     True
# 4    False
# Name: Cabin, dtype: bool

# %%
# Count and display the frequency of each unique value in the 'Cabin' column.
df['Cabin'].value_counts()
# Out:
# Cabin
# G6             4
# B96 B98        4
# C23 C25 C27    4
# F33            3
# D              3
#               ..
# C91            1
# D45            1
# F G63          1
# A34            1
# E63            1
# Name: count, Length: 147, dtype: int64

# %%
# Drop the 'Name' column from the DataFrame 'df' along the columns (axis=1), but the original DataFrame 'df' remains unchanged.
df.drop('Name', axis=1)
# Out:
#      PassengerId Survived  Pclass     Sex   Age  SibSp  Parch      Ticket  \
# 0            343       No       2    male  28.0      0      0      248740
# 1             76       No       3    male  25.0      0      0      348123
# 2            641       No       3    male  20.0      0      0      350050
# 3            568       No       3  female  29.0      0      4      349909
# 4            672       No       1    male  31.0      1      0  F.C. 12750
# ..           ...      ...     ...     ...   ...    ...    ...         ...
# 886           10      Yes       2  female  14.0      1      0      237736
# 887           61       No       3    male  22.0      0      0        2669
# 888          535       No       3  female  30.0      0      0      315084
# 889          102       No       3    male   NaN      0      0      349215
# 890          428      Yes       2  female  19.0      0      0      250655
#
#         Fare  Cabin Embarked
# 0    13.0000    NaN        S
# ...

# %%
# Fill missing values in the 'Cabin' column with 'G6' and make the change to the DataFrame 'df' in place.
df['Cabin'].fillna('G6', inplace=True)

# Display the tail (last few rows) of the DataFrame 'df' to show the updated data.
df.tail()
# Out:
#      PassengerId Survived  Pclass  \
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex   Age  SibSp  \
# 886                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 887                              Sirayanian, Mr. Orsen    male  22.0      0
# 888                                Cacic, Miss. Marija  female  30.0      0
# 889                   Petroff, Mr. Pastcho ("Pentcho")    male   NaN      0
# 890  Phillips, Miss. Kate Florence ("Mrs Kate Louis...  female  19.0      0
#
#      Parch  Ticket     Fare Cabin Embarked
# 886      0  237736  30.0708    G6        C
# 887      0    2669   7.2292    G6        C
# 888      0  315084   8.6625    G6        S
# 889      0  349215   7.8958    G6        S
# 890      0  250655  26.0000    G6        S

# %%
# Fill missing values in the 'Age' column with the mean of the non-missing values in the same column, and update the DataFrame 'df' in place.
df['Age'].fillna(df['Age'].mean(), inplace=True)

# Display the tail (last few rows) of the DataFrame 'df' to show the updated data.
df.tail()
# Out:
#      PassengerId Survived  Pclass  \
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex        Age  \
# 886                Nasser, Mrs. Nicholas (Adele Achem)  female  14.000000
# 887                              Sirayanian, Mr. Orsen    male  22.000000
# 888                                Cacic, Miss. Marija  female  30.000000
# 889                   Petroff, Mr. Pastcho ("Pentcho")    male  29.699118
# 890  Phillips, Miss. Kate Florence ("Mrs Kate Louis...  female  19.000000
#
#      SibSp  Parch  Ticket     Fare Cabin Embarked
# 886      1      0  237736  30.0708    G6        C
# 887      0      0    2669   7.2292    G6        C
# 888      0      0  315084   8.6625    G6        S
# 889      0      0  349215   7.8958    G6        S
# 890      0      0  250655  26.0000    G6        S

# %%
# Calculate the number of missing values in each column of the DataFrame 'df' and return the results.
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       2
# dtype: int64

# %%
# Import necessary libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Read the Titanic dataset into a DataFrame 'df' using ';' as the delimiter
df = pd.read_csv("titanic-passengers.csv", delimiter=';')

# Create a count plot of the 'Sex' column to visualize the distribution of passengers by gender
sns.countplot(x='Sex', data=df)

# Rotate the x-axis labels for better readability
plt.xticks(rotation=-45)
# Out:
# (array([0, 1]), [Text(0, 0, 'male'), Text(1, 0, 'female')])

# %%
# Import the Matplotlib library for plotting
import matplotlib.pyplot as plt

# Read the Titanic dataset into a DataFrame 'df' using ';' as the delimiter
df = pd.read_csv("titanic-passengers.csv", delimiter=';')

# Set the title and labels for the histogram
plt.title('Histogram of Different Ages')
plt.xlabel('Age')

# Create a histogram of the 'Age' column to visualize the age distribution
df['Age'].plot.hist()
# Out:
# <Axes: title={'center': 'Histogram of Different Ages'}, ylabel='Frequency'>

# %%
# Import necessary libraries
import matplotlib.pyplot as plt
import seaborn as sns

# Define a function to plot the correlation heatmap for a DataFrame
def plot_correlation_map(df):
    # Select numeric columns from the DataFrame
    numeric_columns = df.select_dtypes(include=['number'])
    
    # Calculate the correlation matrix
    corr = numeric_columns.corr()
    
    # Set up the size of the plot
    plt.figure(figsize=(12, 10))
    
    # Define the color palette for the heatmap
    cmap = sns.diverging_palette(220, 10, as_cmap=True)
    
    # Create the heatmap with annotations
    sns.heatmap(corr, cmap=cmap, square=True, cbar_kws={'shrink': 0.9}, annot=True, annot_kws={'fontsize': 12})
    
    # Display the plot
    plt.show()

# Call the function with the DataFrame 'df' to visualize the correlation heatmap
plot_correlation_map(df)

# %%
# Import necessary libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder

# Define the Title_Dictionary with title mappings
Title_Dictionary = {
    "Capt": "Officer",
    "Col": "Officer",
    "Major": "Officer",
    "Dr": "Officer",
    "Rev": "Officer",
    "Jonkheer": "Royalty",
    "Don": "Royalty",
    "Sir": "Royalty",
    "Lady": "Royalty",
    "the Countess": "Royalty",
    "Dona": "Royalty",
    "Mme": "Miss",
    "Mlle": "Miss",
    "Miss": "Miss",
    "Ms": "Mrs",
    "Mr": "Mr",
    "Mrs": "Mrs",
    "Master": "Master"
}

# Read the Titanic dataset into a DataFrame 'df' using ';' as the delimiter
df = pd.read_csv("titanic-passengers.csv", delimiter=';')

# Add a new 'Title' column based on the modified Title_Dictionary
df['Title'] = df['Name'].apply(lambda name: Title_Dictionary.get(name.split(',')[1].split('.')[0].strip(), "Unknown"))

# Use label encoding to convert 'Title' and 'Sex' into numerical representations
label_encoder = LabelEncoder()
df['Title'] = label_encoder.fit_transform(df['Title'])
df['Sex'] = label_encoder.fit_transform(df['Sex'])

# Calculate the correlation matrix
correlation_matrix = df[['Title', 'Sex', 'Fare', 'Age']].corr()

# Create a heatmap to visualize the correlations
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()
